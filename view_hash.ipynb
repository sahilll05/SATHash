# %%
import numpy as np
import json

# Load data
vectors = np.load("satellite_hash_vectors_v3.npy")

with open("satellite_image_files_v3.json") as f:
    image_data = json.load(f)

image_list = image_data

# Print first 5 mappings
for i in range(5):
    print("Image:", image_list[i])
    print("Hash Vector:", vectors[i])
    print("-" * 50)
# Out:
# Image: S2A_MSIL2A_20170803T094031_N9999_R036_T34TCR_28_12.tif
# Hash Vector: [ 89 163  91  63  48 191 223  81]
# --------------------------------------------------
# Image: S2A_MSIL2A_20170803T094031_N9999_R036_T34TCR_29_12.tif
# Hash Vector: [ 70 200 165 248 196  65  28 212]
# --------------------------------------------------
# Image: S2A_MSIL2A_20170803T094031_N9999_R036_T34TCR_30_09.tif
# Hash Vector: [102 204 165 224 207  65  24 228]
# --------------------------------------------------
# Image: S2A_MSIL2A_20170803T094031_N9999_R036_T34TCR_30_10.tif
# Hash Vector: [230 232 181  80 207  65 186 228]
# --------------------------------------------------
# Image: S2A_MSIL2A_20170803T094031_N9999_R036_T34TCR_30_11.tif
# Hash Vector: [ 76 225 180 249 184  69  28  84]
# --------------------------------------------------
